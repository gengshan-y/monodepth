# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
config = tf.ConfigProto(allow_soft_placement=True)
config.gpu_options.visible_device_list='0'
config.gpu_options.allow_growth=True

im_path = '/ssd0/KITTI/2011_09_26/2011_09_26_drive_0001_sync/image_00/data/0000000000.jpg'
d_path = '/ssd0/KITTI/2011_09_26/2011_09_26_drive_0001_sync/disp_0/0000000000.jpg'

# %%
with tf.Session(config=config) as sess:
    im = tf.image.decode_jpeg(tf.read_file(im_path))
    d = tf.image.decode_jpeg(tf.read_file(d_path))
    d = tf.divide(tf.cast(d, tf.float32), tf.cast(tf.shape(d)[1],tf.float32))  # relative disp
    d0 = tf.image.resize_images(d,  [256, 512], tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    d1 = tf.image.resize_images(d0,  [128, 256], tf.image.ResizeMethod.BILINEAR)
    d2 = tf.image.resize_images(d1,  [64, 128], tf.image.ResizeMethod.BILINEAR)
    d3 = tf.image.resize_images(d2,  [32, 64], tf.image.ResizeMethod.BILINEAR)
    
    e0 = d0 + tf.random_normal(tf.shape(d0),stddev=0.0001)
    
    mask0 = tf.cast(d0>0,tf.float32)
    d0_masked = mask0 * d0
    e0_masked = mask0 * e0
    
    #d0_masked = tf.where(mask0, tf.log(d0), tf.zeros_like(d0))    
    #e0_masked = tf.where(mask0, tf.log(e0), tf.zeros_like(e0))
    
    sup_loss = tf.abs(d0_masked-e0_masked)
    sup_loss = tf.reduce_mean(sup_loss)
    
    
    im = im.eval()
    d = d.eval()
    d0 = d0.eval()
    d1 = d1.eval()
    d2 = d2.eval()
    d3 = d3.eval()
    e0 = e0.eval()
    mask0 = mask0.eval()
    
    d0_masked = d0_masked.eval()
    e0_masked = e0_masked.eval()
    sup_loss = sup_loss.eval()
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-18-ee9b174ea7be> in <module>()
#      21
#      22
# ---> 23     im = im.eval()
#      24     d = d.eval()
#      25     d0 = d0.eval()
#
# /home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in eval(self, feed_dict, session)
#     565
#     566     """
# --> 567     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     568
#     569
#
# /home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in _eval_using_default_session(tensors, feed_dict, graph, session)
#    3727                        "the tensor's graph is different from the session's "
#    3728                        "graph.")
# -> 3729   return session.run(tensors, feed_dict)
#    3730
#    3731
#
# /home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# NotFoundError: /ssd0/KITTI/2011_09_26/2011_09_26_drive_0001_sync/image_00/data/0000000000.jpg
# 	 [[Node: ReadFile_3 = ReadFile[_device="/job:localhost/replica:0/task:0/cpu:0"](ReadFile_3/filename)]]
#
# Caused by op u'ReadFile_3', defined at:
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-18-ee9b174ea7be>", line 2, in <module>
#     im = tf.image.decode_jpeg(tf.read_file(im_path))
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/gen_io_ops.py", line 202, in read_file
#     result = _op_def_lib.apply_op("ReadFile", filename=filename, name=name)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2327, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1226, in __init__
#     self._traceback = _extract_stack()
#
# NotFoundError (see above for traceback): /ssd0/KITTI/2011_09_26/2011_09_26_drive_0001_sync/image_00/data/0000000000.jpg
# 	 [[Node: ReadFile_3 = ReadFile[_device="/job:localhost/replica:0/task:0/cpu:0"](ReadFile_3/filename)]]

# %%
im.shape
# Out:
# (375, 1242, 1)

# %%
# plt.hist(diff.flatten());
np.sum(diff!=0)
# Out:
# 18766

# %%
plt.hist(d0_masked.flatten());

# %%
np.sum(sup_loss)
# Out:
# 0.00058916031

# %%
fig = plt.figure(figsize = (20,5))
plt.imshow(d0_masked[:,:,0],cmap='gray')
plt.colorbar()

# %%
fig = plt.figure(figsize = (20,5))
plt.imshow(d[:,:,0])
plt.colorbar()

# %%
fig = plt.figure(figsize = (20,5))
plt.imshow(d0[:,:,0])
plt.colorbar()

# %%
print '%f,%f,%f,%f' % (np.max(d0),np.max(d1),np.max(d2),np.max(d3))
# Out:
# 0.049114,0.047504,0.046699,0.044283

# %%
fig = plt.figure(figsize = (20,5))
plt.imshow(d1[:,:,0])
plt.colorbar()

# %%
fig = plt.figure(figsize = (20,5))
plt.imshow(d2[:,:,0])
plt.colorbar()

# %%
fig = plt.figure(figsize = (20,5))
plt.imshow(d3[:,:,0])
plt.colorbar()

# %%
plt.hist(d0[d0>0].flatten(),bins=100,range=(0,0.02));
print np.sum(d0>0)
# Out:
# 20742

# %%
plt.hist(d1[d1>0].flatten(),bins=100,range=(0,0.06));
np.sum(d1>0)
# Out:
# 5220

# %%
plt.hist(d2[d2>0].flatten(),bins=100,range=(0,0.06));
np.sum(d2>0)
# Out:
# 1290

# %%
plt.hist(d3[d3>0].flatten(),bins=100,range=(0,0.06));
np.sum(d3>0)
# Out:
# 342

# %%
fig = plt.figure(figsize = (20,5))
plt.imshow(d[:,:,0])
plt.colorbar()
