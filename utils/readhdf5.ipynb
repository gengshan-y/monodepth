# %%
import h5py
import cv2
% matplotlib inline
from matplotlib import pyplot as plt
import numpy as  np

# %%
f = h5py.File('/home/gengshay/code/sparse-to-dense/a.h5','r')

# %%
inn = np.asarray(f['in'])
out = np.asarray(f['out'])
targ = np.asarray(f['pic'])

# %%
targ[np.isnan(targ)]=0

# %%
plt.figure(figsize=(20,10))
plt.imshow(inn.astype(np.int),cmap='plasma')
plt.figure(figsize=(40,20))
plt.imshow(out.astype(np.int),cmap='plasma')
plt.figure(figsize=(20,10))
plt.imshow(targ.astype(np.int),cmap='plasma')

# %%
print np.sum((targ > 0).astype(np.int))
print np.sum((out > 0).astype(np.int))
print np.sum((inn > 0).astype(np.int))
# Out:
# 13393
# 207936
# 13393
# /home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.

# %%
f = h5py.File('/scratch/gengshay/s2d/kitti/train/00/00001-L.h5','r')

# %%
im = np.asarray(f['depth'],np.float32)
mask = (im > 0)
data = im[mask]
print np.sum(mask)
plt.figure(figsize=(20,10))
plt.hist(data.flatten(),bins=80);
# Out:
# 19419

# %%
# test png file
imname1 = 'test'
cv2.imwrite(imname1 + '.jpg',im); cv2.imwrite(imname1 + '.png',im)
jpg = cv2.imread(imname1 + '.jpg',cv2.IMREAD_GRAYSCALE); png = cv2.imread(imname1 + '.png',cv2.IMREAD_GRAYSCALE)

# %%
#mask = ~np.isnan(targ) 
mask = (im > 0)
diff1 = np.abs(im-jpg); diff2 = np.abs(im - png)
plt.hist(jpg[mask],bins=100);
print('error=%d' % sum(diff1[mask]));
# Out:
# error=38783

# %%
plt.hist(png[mask],bins=100);
print('error=%d' % sum(diff2[mask]))
# Out:
# error=5143

# %%
plt.hist(im[mask],bins=100);
