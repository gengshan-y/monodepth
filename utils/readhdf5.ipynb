# %%
import h5py
import cv2
% matplotlib inline
from matplotlib import pyplot as plt
import numpy as  np

# %%
f = h5py.File('/home/gengshay/code/sparse-to-dense/a.h5','r')

# %%
inn = np.asarray(f['in'])
out = np.asarray(f['out'])
targ = np.asarray(f['pic'])

# %%
np.min(targ[~np.isnan(targ)])
# Out:
# 5.3085938

# %%
np.sum((inn != 0).astype(np.int))
# Out:
# 101

# %%
plt.figure(figsize=(20,10))
plt.imshow(inn.astype(np.int),cmap='gray')

# %%
plt.figure(figsize=(20,10))
plt.imshow(out.astype(np.int))

# %%
plt.figure(figsize=(20,10))
plt.imshow(targ.astype(np.int))

# %%
print np.sum((targ > 0).astype(np.int))
print np.sum((out > 0).astype(np.int))
print np.sum((inn > 0).astype(np.int))
# Out:
# 13606
# 207936
# 101
# /home/gengshay/softwares/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.

# %%
228 * 912
# Out:
# 207936

# %%
plt.hist(f['pic']);

# %%
f = h5py.File('/scratch/gengshay/s2d/kitti/train/00/00001-L.h5','r')

# %%
plt.imshow(np.asarray(f['depth']).astype(np.int))

# %%
plt.hist(f['depth']);
